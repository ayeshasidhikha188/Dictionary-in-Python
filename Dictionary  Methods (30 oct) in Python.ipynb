# %% [markdown]
# # Mandatory Task (30/10/23)
# # (a) Dictionary
# * Dictionaries are key & value pairs enclosed in { }
# * key & value are seperated by ':'  while key and value pairs are sperated by ','
# * keys are mapped to their values
# * In dictionaries , keys are unique, we cant have duplicate keys, we can duplicate values
# * Dictionaries are unordered & mutable
# * { } is an empty dictionary
# * dict is class of dictionary
# * Dictionary holds key:value pair.
# ![image.png](attachment:image.png)

# %%
#dictionary, key;value
x={1:[1,2,3],'ayesha':(4,5,6)}  #'1' is int and 'ayesha'is string,('f','g') is tuple
print(x,type(x))
# Out:
# {1: [1, 2, 3], 'ayesha': (4, 5, 6)} <class 'dict'>

# %% [markdown]
# ### Creating a Dictionary
# * In Python, a dictionary can be created by placing a sequence of elements within curly {} braces, separated by ‘comma’. * Dictionary holds pairs of values, one being the Key and the other corresponding pair element being its Key:value.
# * Values in a dictionary can be of any data type and can be duplicated, whereas keys can’t be repeated and must be immutable

# %%
x={1:[1,2,3],'ayesha':(4,5,6)} 
print(x,type(x))
# Out:
# {1: [1, 2, 3], 'ayesha': (4, 5, 6)} <class 'dict'>

# %% [markdown]
# ## creating an empty  dictionary
# * Empty dictionary can also be created by using dict().
# * An empty dictionary can be created by just placing to curly braces{}.

# %%
# using {} :
x={}
print(x,type(x))
# Out:
# {} <class 'dict'>

# %%
#using class dict()
x=dict()
print(x,type(x))
# Out:
# {} <class 'dict'>

# %% [markdown]
# ## Nested Dictionary
# Nesting Dictionary means putting a dictionary inside another dictionary. Nesting is of great use as the kind of information we can model in programs is expanded greatly.
#
# nested_dict = {'dict1': {'key_A': 'value_A'},
#                'dict2': {'key_B': 'value_B'}}
#                ![image.png](attachment:image.png)

# %%
s={2:{1:'ashu'},3:{3:'ayesha'}}
print(s)
# Out:
# {2: {1: 'ashu'}, 3: {3: 'ayesha'}}

# %% [markdown]
# ### Length of dictionary
# len()is used to find the length of the dictionary

# %%
s={2:{1:'ashu'},3:{3:'ayesha'}}
len(s)
# Out:
# 2

# %% [markdown]
# ### Range
# * range()populates a numbers within a given range
# * syntax for range() is : range(start,end,step)
#   * start is starting number
#   * end is till end , not including end
#   * step is step size
# * default values of start is zero and step is +1

# %%
r= range(1,11)  # till end means upto 10
print(r,type(r),hex(id(r)),sep='\n')
# Out:
# range(1, 11)
# <class 'range'>
# 0x1ea5e74a3a0

# %% [markdown]
# ## Dictionary Methods
# ![image.png](attachment:image.png)

# %%
dir(dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %% [markdown]
# ### Methods in Dictionary
# * Dictionary is like a map that is used to store data in the form of a key: value pair.
# * Python provides various built-in functions to deal with dictionaries
# 1. clear()
#
# * Removes all items from the dictionary
#
# 2. copy()
#
# * Returns a shallow copy of the dictionary
#
# 3. fromkeys()
#
# * Creates a dictionary from the given sequence
#
# 4. get()
#
# * Returns the value for the given key
#
# 5. items()
#
# * Return the list with all dictionary keys with values
#
# 6. keys()
#
# * Returns a view object that displays a list of all the keys in the dictionary in order of insertion
#
# 7. pop()
#
# * Returns and removes the element with the given key
#
# 8. popitem()
#
# * Returns and removes the key-value pair from the dictionary
#
# 9. setdefault()
#
# * Returns the value of a key if the key is in the dictionary else inserts the keywith a value to the dictionary
#
# 10. values()
#
# * Updates the dictionary with the elements from another dictionary
#
# 11. update()
#
# * Returns a list of all the values available in a given dictionary

# %% [markdown]
# ## 1.  clear()
# * The clear() method removes all items from the dictionary.
# * Syntax:dict.clear()
# ###### Parameters:
# * The clear() method doesnot take any parameters.
# ##### Returns:
# * The clear() method doesnot return any value.
# ![image.png](attachment:image.png)

# %%
x={'k1':1,'k2':2,'k3':3}
print(x)
# Out:
# {'k1': 1, 'k2': 2, 'k3': 3}

# %%
x.clear()
print(x)
# Out:
# {}

# %% [markdown]
# ## 2. copy()
# * copy() method returns a shallow copy of the dictionary
# * Syntax:  dict.copy()
# ##### parameters
# * no parameters.
# ##### Return:
# * This method doesn’t modify the original, dictionary just returns copy of the dictionary.
# ![copy%20d%20.jpg](attachment:copy%20d%20.jpg)

# %%
print(a)
print(a,type(a),hex(id(a)),sep='/n')
s=a.copy()
print(s,type(s),hex(id(s)),sep='/n')
# Out:
# {'k1': 1, 'k2': 2, 'k3': 3, 'k5': 5, 'k6': 6, 'k7': 7, 'k8': 9}
# {'k1': 1, 'k2': 2, 'k3': 3, 'k5': 5, 'k6': 6, 'k7': 7, 'k8': 9}/n<class 'dict'>/n0x1c396040f80
# {'k1': 1, 'k2': 2, 'k3': 3, 'k5': 5, 'k6': 6, 'k7': 7, 'k8': 9}/n<class 'dict'>/n0x1c39680c580

# %% [markdown]
# ## 3. fromkeys()
# * fromkeys() function returns the dictionary with key mapped and specific value.
# * It creates a new dictionary from the given sequence with the specific value.
# * Syntax : fromkeys(seq, val)
# ##### Parameters :
# * seq : The sequence to be transformed into a dictionary.
# * val : Initial values that need to be assigned to the generated keys. Defaults to None.
# ##### Returns :
# * A dictionary with keys mapped to None if no value is provided, else to the value provided in the field.
# ![from%20keysd%20.jpg](attachment:from%20keysd%20.jpg)

# %%
#fromkeys
a={'a':'ayesha','s':'sidhikha'}
b=dict.fromkeys(a)
print(b)
# Out:
# {'a': None, 's': None}

# %%
c={'a':'ayesha','s':'sidhikha'} #no effect on 'c'
z=c.fromkeys(a)
print(z)
# Out:
# {'a': None, 's': None}

# %%
z=dict.fromkeys(a)
print(z)
# Out:
# {'a': None, 's': None}

# %% [markdown]
# ## 4. get()
# * get() Method return the value for the given key if present in the dictionary.
# * If not, then it will return None (if get() is used with only one argument).
# * Syntax : Dict.get(key, default=None)
# ##### Parameters:
# * key: The key name of the item you want to return the value from
# * Value: (Optional) Value to be returned if the key is not found. The default value is None.
# ##### Returns:
# * Returns the value of the item with the specified key or the default value.
# ![get%20d.jpg](attachment:get%20d.jpg)

# %%
a={'k1': 1, 'k2': 2, 'k3': 3, 'k5': 5, 'k6': 6, 'k7': 7, 'k8': 9}
print(a)
# Out:
# {'k1': 1, 'k2': 2, 'k3': 3, 'k5': 5, 'k6': 6, 'k7': 7, 'k8': 9}

# %%
a.get('k3') # get method
# Out:
# 3

# %% [markdown]
# ## 5. items()
# *  items() method is used to return the list with all dictionary keys with values.
# * Syntax: dictionary.items()
# ##### Parameters:
# * This method takes no parameters.
# ##### Returns:
# * A view object that displays a list of a given dictionary’s (key, value) tuple pair.
# ![items.jpg](attachment:items.jpg)

# %%
# items
# it reurns both key & values as tuples 
# it returns dict_items
a.items()
# Out:
# dict_items([('k1', 1), ('k2', 2), ('k3', 3), ('k5', 5), ('k6', 6), ('k7', 7), ('k8', 9)])

# %% [markdown]
# ## 6. keys()
# * keys() method  returns a view object that displays a list of all the keys in the dictionary
# * Syntax: dict.keys()
# ##### Parameters:
# * There are no parameters.
#
# ##### Returns:
# * A view object is returned that displays all the keys.
# * This view object changes according to the changes in the dictionary.
# ![keys%20pp.jpg](attachment:keys%20pp.jpg)

# %%
# it returns dict_keys object
akeys=a.keys()
print(akeys,type(akeys),hex(id(akeys)),len(akeys),sep='\n')
# Out:
# dict_keys(['k1', 'k2', 'k3', 'k5', 'k6', 'k7', 'k8'])
# <class 'dict_keys'>
# 0x1c395c724d0
# 7

# %%
aKeys=list(akeys)
print(akeys,type(akeys),hex(id(akeys)),len(akeys),sep='\n')
# Out:
# dict_keys(['k1', 'k2', 'k3', 'k5', 'k6', 'k7', 'k8'])
# <class 'dict_keys'>
# 0x1c395c724d0
# 7

# %% [markdown]
# ## 7.  pop()
# * pop() method removes and returns the specified element from the dictionary.
# * Syntax: dict.pop(key, def)
# ##### Parameters :
# * key : The key whose key-value pair has to be returned and removed.
# * def : The default value to return if specified key is not present.
# ##### Returns :
# * The value associated with the deleted key-value pair, if the key is present.
# * Default value if specified if key is not present.
# * KeyError, if key not present and default value not specified
# ![popp.jpg](attachment:popp.jpg)

# %%
#pop()
# dict pop takes only one argument that argument is the key
# and pop out the corresponding value
a.pop('k1')
# Out:
# 1

# %%
a #here 'k1' corresponding value
# Out:
# {'k2': 2, 'k3': 3, 'k5': 5, 'k6': 6, 'k7': 7, 'k8': 9}

# %% [markdown]
# ## 8.  popitem()
# * popitem() method removes the last inserted key-value pair from the dictionary and returns it as a tuple.
# * Syntax : dict.popitem()
# ##### Parameters :
# * None
# ##### Returns :
# * A tuple containing the arbitrary key-value pair from dictionary. That pair is removed from dictionary.

# %%
 # pop items removes and returns last key and value pair
 a.popitem() # 'k8' is last keyvalue
# Out:
# ('k8', 9)

# %% [markdown]
# ## 9. setdefault()
# * setdefault() returns the value of a key (if the key is in dictionary).
# * Else, it inserts a key with the default value to the dictionary.
# * Syntax: dict.setdefault(key, default_value)
# ##### Parameters:
# * It takes two parameters:
# * key – Key to be searched in the dictionary.
# * default_value (optional) – Key with a value * default_value is inserted to the dictionary if key is not in the dictionary.
# * If not provided, the default_value will be None.
# ##### Returns:
# * Value of the key if it is in the dictionary.
# * None if key is not in the dictionary and default_value is not specified.
# * default_value if key is not in the dictionary and default_value is specified.
# ![setdefault.jpg](attachment:setdefault.jpg)

# %%
x={'name':'ayesha','age':25,'roll_no':8}
x.setdefault('name')
# Out:
# 'ayesha'

# %% [markdown]
# ## 10.  update()
# * update() method updates the dictionary with the elements from another dictionary object or from an iterable of key/value pairs.
# * Syntax: dict.update([other])
# ##### Parameters:
# * This method takes either a dictionary or an iterable object of key/value pairs (generally tuples) as parameters.
# ##### Returns:
# * It doesn’t return any value but updates the Dictionary with elements from a dictionary object or an iterable object of key/value pairs.
# ![jeejcms2.png](attachment:jeejcms2.png)

# %%
x={'k1':1,'k2':2,'k3':3}
print(x)
# Out:
# {'k1': 1, 'k2': 2, 'k3': 3}

# %%
x.update([('k5',5),('k6',6)]) # using tuple one method
print(x)
# Out:
# {'k1': 1, 'k2': 2, 'k3': 3, 'k5': 5, 'k6': 6}

# %% [markdown]
# ## 11.  values()
# * values() is an inbuilt method in Python programming language that returns a view object. The view object contains the values of the dictionary, as a list. * If you use the type() method on the return value, you get “dict_values object”. It must be cast to obtain the actual list.
# * Syntax: dictionary_name.values()
# ##### Parameters:
# * There are no parameters
# ##### Returns:
# * A list of all the values available in a given dictionary. The values have been stored in a reversed manner.
# ![values.jpg](attachment:values.jpg)

# %%
#values will return in dict_values 
a={'k1': 1, 'k2': 2, 'k3': 3, 'k5': 5, 'k6': 6, 'k7': 7, 'k8': 9}
avalues=a.values()
print(avalues,type(avalues),hex(id(avalues)),len(avalues),sep='\n')
# Out:
# dict_values([1, 2, 3, 5, 6, 7, 9])
# <class 'dict_values'>
# 0x1c395c75e10
# 7

# %%
avalues=list(avalues)
print(avalues,type(avalues),hex(id(avalues)),len(avalues),sep='\n')
# Out:
# [1, 2, 3, 5, 6, 7, 9]
# <class 'list'>
# 0x1c3968155c0
# 7

# %%
a={'k1': 1, 'k2': 2, 'k3': 3, 'k5': 5, 'k6': 6, 'k7': 7, 'k8': 9}
a.values()
# Out:
# dict_values([1, 2, 3, 5, 6, 7, 9])

# %% [markdown]
# # String Methods
# ## Maketrans
# * maketrans() function is used to construct the transition table i.e specify the list of characters that need to be replaced in the whole string or the characters that need to be deleted from the string.
# * Syntax:maketrans(str1, str2, str3)
# ##### Parameters:
# * str1: Specifies the list of characters that need to be replaced.
# * str2: Specifies the list of characters with which the characters need to be replaced.
# * str3: Specifies the list of characters that need to be deleted.
# ##### Returns:
# * Returns the translation table which specifies the conversions that can be used by translate()
# ![makestrans.jpg](attachment:makestrans.jpg)

# %%
#makestrans
v='!@#ayesha#@!'
print(v)
# Out:
# !@#ayesha#@!

# %%
a=v.maketrans({'@':'s','s':'7','a':'zz'}) 
print(a)#64 ,115,95 is ascii default
# Out:
# {64: 's', 115: '7', 97: 'zz'}

# %% [markdown]
# ## translate()
# *  translate() returns a string that is a modified string of givens string according to given translation mappings.
# #####  translate() :
# * translate() is a built-in method in Python that is used to replace specific characters in a string with other characters or remove them altogether.
# * The translate() method requires a translation table that maps the characters to be replaced to their replacements.
# * This table  translate() returns a string that is a modified string of givens string according to given translation mappings. * * This table can be generated using the maketrans() method, which takes two arguments: the characters to be replaced and their replacements.
# * syntax: str.translate(translation_table)
# ![trans.jpg](attachment:trans.jpg)

# %%
v.translate(a) # replaces @ as'a','s' as 117
# Out:
# '!@#ayesha#@!'

# %% [markdown]
# ## (b) Exploring maketrans() and translate() using three inputs

# %% [markdown]
# ##### maketrans()

# %%
# using dictionary
dict = {"a": "123", "b": "456", "c": "789"}
string = 'ashu'
print(string.maketrans(dict))
# Out:
# {97: '123', 98: '456', 99: '789'}

# %% [markdown]
# ##### maketrans() Using 3 strings

# %%
a = "ashu"
b = "asif"
c = "immu"
x='string'
print(x.maketrans(a,b,c))
# Out:
# {97: 97, 115: 115, 104: 105, 117: None, 105: None, 109: None}

# %% [markdown]
# ##### translate()  Using three strings

# %%
a = "Hello!"
x = "ashu"
y = "asif"
z = "immu"
b = a.maketrans(x, y, z)
print(b)
print(a.translate(b))
# Out:
# {97: 97, 115: 115, 104: 105, 117: None, 105: None, 109: None}
# Hello!

# %% [markdown]
# ##  (c) conditional statements
# #####  (i) A simple program using if ,elif &else statements

# %%
marks=90
if marks>=80:
    print('second round') # true it gives output
# Out:
# second round

# %%
marks=75
if marks>=80:
    print('second round') # false it skips entire statement

# %%
marks=90
if marks>=80:
    print("second round")
elif (marks>=70):
    print("d")first roun
elif (marks>=60):
    print("screening round")
else:
    print("study hard")
# Out:
# second round

# %%
marks=76
if marks>=80:
    print("second round")
elif (marks>=70):
    print("first round")
elif (marks>=60):
    print("screening round")
else:
    print("study hard")
# Out:
# first round

# %%
marks=66
if marks>=80:
    print("second round")
elif (marks>=70):
    print("first round")
elif (marks>=60):
    print("screening round")
else:
    print("study hard")
# Out:
# screening round

# %%
marks=90
if marks>=80:
    print("second round")
elif (marks>=70):
    print("first round")
elif (marks>=60):
    print("screening round")
else:
    print("study hard")
# Out:
# second round

# %% [markdown]
# ##### (ii) A simple program using if ,elif &else conditional statements

# %%
marks=56
if marks<=60:
    print("study hard")
elif (marks<=70):
    print("screening round")
elif (marks<=80):
    print("first round")
else:
    print("second round")
# Out:
# study hard

# %%
marks=88
if marks<=60:
    print("study hard")
elif (marks<=70):
    print("screening round")
elif (marks<=80):
    print("first round")
else:
    print("second round")
# Out:
# second round

# %%
marks=78
if marks<=60:
    print("study hard")
elif (marks<=70):
    print("screening round")
elif (marks<=80):
    print("first round")
else:
    print("second round")
# Out:
# first round

# %%
marks=60
if marks<=60:
    print("study hard")
elif (marks<=70):
    print("screening round")
elif (marks<=80):
    print("first round")
else:
    print("second round")
# Out:
# study hard
