# %% [markdown]
# # Conditional Statements
# * Conditional statements are an essential part of programming in Python.
# * They allow you to make decisions based on the values of variables or the result of comparisons.
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### control flow
# * Situations will arise in programming  where we need to make some decisions and based on these decisions we will execute the next block of code.
# * Decision-making statements in programming languages decide the direction(Control Flow) of the flow of program execution.
# ### Types of Control Flow in Python
# * In Python programming language, the type of control flow statements is as follows:
#
#   1.  if statement
#   2.  if-else statement
#   3.  nested-if statement
#   4.  if-elif-else ladder
# ##  if statement
# The if statement is the most simple decision-making statement. It is used to decide whether a certain statement or block of statements will be executed or not.
# Syntax:
# *  if (condition):
#       *  Executes this block if
#       *  condition is true
# * else:
#      * Executes this block if
#      * condition is false
# #### flow chart of if statement
# ![image-2.png](attachment:image-2.png)

# %%
ayeshamarks=90
if ayeshamarks>=80:
    print('second round') # true it gives output
# Out:
# second round

# %% [markdown]
# ## If-Else Statement
# *  if statement alone tells us that if a condition is true it will execute a block of statements and if the condition is false it won’t.
# * But if we want to do something else if the condition is false, we can use the else statement with if statement to execute a block of code when the if condition is false.
# * Syntax:
# * if (condition):
#     *  Executes this block if
#     *  condition is true
# * else:
#     *  Executes this block if
#     *  condition is false
# ##### flow chart of if else statement
# ![image.png](attachment:image.png)

# %%
x = 3
if x == 4:
   print("Yes")
else:
   print("No")
# Out:
# No

# %% [markdown]
# ## Nested if Statement
# * if statement can also be checked inside other if statement. This conditional statement is called a nested if statement.
# * This means that inner if condition will be checked only if outer if condition is true and by this, we can see multiple conditions to be satisfied.
# * Syntax:
# * if (condition1):
#    *  Executes when condition1 is true
#    if (condition2):
#       * Executes when condition2 is true
#    * if Block is end here
# * Block is end here
# ![image.png](attachment:image.png)

# %%
num= int(input())
if num%3==0 : # true goes to other stmt
    if num%2==0:
        print('div by 6')
# Out:
# 12
# div by 6

# %%
marks=int(input('marks scored'))
if marks>=100 or marks<=0: 
    print("enter valid marks")
else:
    if marks>=80:
         print("second round")
    elif (marks>=70):
         print("first round")
    elif (marks>=60):
         print("screening round")
    else:
        print("study hard")
# Out:
# marks scored-99
# enter valid marks

# %% [markdown]
# ## if-elif Statement
# *  if-elif statement is shortcut of if..else chain.
# * While using if-elif statement at the end else block is added which is performed if none of the above if-elif statement is true.
# * Syntax:-
# * if (condition):
#     * statement
# * elif (condition):
#     * statement
#  *
#  *
# * else:
#     * statement
# ![image.png](attachment:image.png)

# %%
marks=int(input('marks scored'))
if marks>=100 or marks<=0: 
    print("enter valid marks")
elif marks>=80:
         print("second round")
elif (marks>=70):
         print("first round")
elif (marks>=60):
         print("screening round")
else:
        print("study hard")
# Out:
# marks scored70
# first round

# %% [markdown]
# ## Task Programs:

# %% [markdown]
# ### 1. Write a Python program that asks the user for their age and prints "You are an adult" if the age is 18 or older, otherwise prints "You are a minor'

# %%
age=int(input('age: ')) # giving age as input 
if age>=18: #checks age is above '18'
    print('you are an adult') #prints if age is above '18'
else: #'if statement fail then else statement executes'
    print('you are a minor') #prints age is below '18'
# Out:
# age: 20
# you are an adult

# %%
age=int(input('age:')) # giving age as input 
if age>=18: #checks age is above '18'
    print('you are an adult') #prints if age is above '18'
else: #'if statement fail then else statement executes'
    print('you are a minor') #prints age is below '18'
# Out:
# age:16
# you are a minor

# %% [markdown]
# ### 2. Write a program that takes a numerical grade (out of 100) as input and prints the corresponding letter grade according to the following scale:
# * 90-100: A
# * 80-89: B
# * 70-79: C
# * 60-69: D
# * Below 60: F

# %%
grade=int(input('Grade:')) #giving input as grade
if grade in range(90,101) : #checks grade is in between 90-100
    print("A") #if grade is above 90 then prints 'A'
elif grade in range(80,90):#checks grade is in between 80-90
         print("B")#if grade is in between 80-90 then prints 'B'
elif (grade in range(70,80)): 
         print("C")#if grade is in between 70-80 then prints 'C'
elif (grade in range(60,70)):
         print("D")#if grade is in between 60-70  then prints 'D'
elif (grade<=60):
        print("F")#if grade is below 60 then prints 'F'
# Out:
# Grade:95
# A

# %%
grade=int(input('Grade:')) #giving input as grade
if grade in range(90,101) : #checks grade is in between 90-100
    print("A") #if grade is above 90 then prints 'A'
elif grade in range(80,90):#checks grade is in between 80-90
         print("B")#if grade is in between 80-90 then prints 'B'
elif (grade in range(70,80)): 
         print("C")#if grade is in between 70-80 then prints 'C'
elif (grade in range(60,70)):
         print("D")#if grade is in between 60-70  then prints 'D'
elif (grade<=60):
        print("F")#if grade is below 60 then prints 'F'
# Out:
# Grade:88
# B

# %%
grade=int(input('Grade:')) #giving input as grade
if grade in range(90,101) : #checks grade is in between 90-100
    print("A") #if grade is above 90 then prints 'A'
elif grade in range(80,90):#checks grade is in between 80-90
         print("B")#if grade is in between 80-90 then prints 'B'
elif (grade in range(70,80)): 
         print("C")#if grade is in between 70-80 then prints 'C'
elif (grade in range(60,70)):
         print("D")#if grade is in between 60-70  then prints 'D'
elif (grade<=60):
        print("F")#if grade is below 60 then prints 'F'
# Out:
# Grade:76
# C

# %%
grade=int(input('Grade:')) #giving input as grade
if grade in range(90,101) : #checks grade is in between 90-100
    print("A") #if grade is above 90 then prints 'A'
elif grade in range(80,90):#checks grade is in between 80-90
         print("B")#if grade is in between 80-90 then prints 'B'
elif (grade in range(70,80)): 
         print("C")#if grade is in between 70-80 then prints 'C'
elif (grade in range(60,70)):
         print("D")#if grade is in between 60-70  then prints 'D'
elif (grade<=60):
        print("F")#if grade is below 60 then prints 'F'
# Out:
# Grade:66
# D

# %%
grade=int(input('Grade:')) #giving input as grade
if grade in range(90,101) : #checks grade is in between 90-100
    print("A") #if grade is above 90 then prints 'A'
elif grade in range(80,90):#checks grade is in between 80-90
         print("B")#if grade is in between 80-90 then prints 'B'
elif (grade in range(70,80)): 
         print("C")#if grade is in between 70-80 then prints 'C'
elif (grade in range(60,70)):
         print("D")#if grade is in between 60-70  then prints 'D'
elif (grade<=60):
        print("F")#if grade is below 60 then prints 'F'
# Out:
# Grade:45
# F

# %% [markdown]
# ## 3.Write a program that calculates the Body Mass Index (BMI) of a person. The user should input their weight in kilograms and height in meters. The program should then print whether the person is underweight, normal weight, overweight, or obese

# %%
weight = int(input('Enter weight in kilograms: ')) # int input accepts integer values
height = int(input('Enter height in meters: ')) # float input accepts  flaot values
# To calculate BMI if height and weight is given then we have formula
bmi = weight/(height**2)
#Classification	BMI range - kg/m2
#Severe Thinness	    < 16
#Moderate Thinness	16 - 17
#Mild Thinness	    17 - 18.5
#Normal	            18.5 - 25
#Overweight	        25 - 30
#Obese Class I	    30 - 35
#Obese Class II	    35 - 40
#Obese Class III	    > 40
if bmi <18.5: # to print under weight
    print("Underweight")
elif 18.5<=bmi and bmi<=25.0:
    print("Normal weight") ## to print Normal weight
elif 25<=bmi and bmi<=30.0:
    print("Overweight")  ## to print overweight 
else:
        print("Obese") # above 30 it prints obese
# Out:
# Enter weight in kilograms: 45
# Enter height in meters: 5
# Underweight

# %% [markdown]
# ### 4. Write a program that asks the user for three numbers and prints the maximum of the three.

# %%
a=int(input('x :')) # gives integer as input 
b=int(input('y: '))  # gives integer as input 
c=int(input('z: '))  # gives integer as input 
if a>b and a>c: # checks a is greater than b & c
    print('x is maximum') # prints x is max
elif b>a and b>c: # checks b is greater than a & c
    print('y is maximum') # prints x is max
elif c>a and c>b:  # checks c is greater than a & b
    print('z is maximum') # prints z is max
# Out:
# x :340
# y: 890
# z: 999
# z is maximum

# %% [markdown]
# ### 5. Write a program that asks the user for a temperature (in Celsius) and prints "It's freezing"if the temperature is below 0, "It's cool" if it's between 0 and 10, "It's warm" if it's between 10 and 20, and "It's hot" if it's above 20

# %%
t = int(input("Temperature in Celsius: ")) #input value is given in int as temperature 

if t < 0: # if temp value is below 0 freezing is printed
    print("It's freezing") 
elif t<=0 and t<= 10: # if temp value is between 0 and 10  cool is printed
    print("It's cool") 
elif t<=10 and t<= 20: # if temp value is between 10 and 20  warm is printed
    print("It's warm")
else:# if temp value is above 20 hot is printed
    print("It's hot")
# Out:
# Temperature in Celsius: 0
# It's cool

# %%
t = int(input("Temperature in Celsius: ")) #input value is given in int as temperature 
if t < 0: # if temp value is below 0 freezing is printed
    print("It's freezing") 
elif t<=0 and t<= 10: # if temp value is between 0 and 10  cool is printed
    print("It's cool") 
elif t<=10 and t<= 20: # if temp value is between 10 and 20  warm is printed
    print("It's warm")
else:# if temp value is above 20 hot is printed
    print("It's hot")
# Out:
# Temperature in Celsius: 7
# It's warm

# %%
t = int(input("Temperature in Celsius: ")) #input value is given in int as temperature 
if t < 0: # if temp value is below 0 freezing is printed
    print("It's freezing") 
elif t<=0 and t<= 10: # if temp value is between 0 and 10  cool is printed
    print("It's cool") 
elif t<=10 and t<= 20: # if temp value is between 10 and 20  warm is printed
    print("It's warm")
else:# if temp value is above 20 hot is printed
    print("It's hot")
# Out:
# Temperature in Celsius: 15
# It's hot

# %% [markdown]
# ### 6. Write a program that asks the user for a number (1-7) and prints the corresponding day of the week.

# %%
a=int(input('Day: ')) # input given is an integer
if 7>=a<=1:  ## Days must be between 1 to 7
    if a == 1:
        print('Sunday') ## to print sunday must be given 1
elif a == 2:
    print('Monday')   ## to print monday must be given 2
elif a == 3:
    print('Tuesday')   ## to print tuesday must be given 3
elif a == 4:
    print('Wednesday')  ## to print wednesday must be given 4
elif a == 5:
    print('Thursday') ## to print thursday must be given 5
elif a == 6:
    print('Friday')    ## to print friday must be given 6         
else:
    print('Saturday')   ## input 7 is given it will print saturday
# Out:
# Day: 1
# Sunday

# %%
a=int(input('Day: ')) # input given is an integer
if 7>=a<=1:  ## Days must be between 1 to 7
    if a == 1:
        print('Sunday') ## to print sunday must be given 1
elif a == 2:
    print('Monday')   ## to print monday must be given 2
elif a == 3:
    print('Tuesday')   ## to print tuesday must be given 3
elif a == 4:
    print('Wednesday')  ## to print wednesday must be given 4
elif a == 5:
    print('Thursday') ## to print thursday must be given 5
elif a == 6:
    print('Friday')    ## to print friday must be given 6         
else:
    print('Saturday')   ## input 7 is given it will print saturday
# Out:
# Day: 5
# Thursday

# %% [markdown]
# ### 7. Write a program that asks the user for a number and prints "In range" if the number is between 10 and 20 (inclusive), and "Out of range" otherwise.

# %%
a = int(input("Number: ")) # input given 

if 10 <= a <= 20:   # if num value is between 10 and 20 it will print in range
    print("In range")   
else: # if num value is not between 10 and 20 it will print out of range
    print("Out of range")
# Out:
# Number: 15
# In range

# %%
a = int(input("Number: ")) # input given 

if 10 <= a <= 20:   # if num value is between 10 and 20 it will print in range
    print("In range")   
else: # if num value is not between 10 and 20 it will print out of range
    print("Out of range")
# Out:
# Number: 25
# Out of range

# %% [markdown]
# ### 8. Write a program that asks the user for an integer and prints whether it's even or odd.

# %%
a=int(input('Integer: ')) # input given 
if a%2==0 :# checks that input is divisible by '2'
    print('even') # if it is divisible by '2' it prints 'even'
else: # if it is not divisible by '2' it prints 'odd'
    print('odd')
# Out:
# Integer: 6
# even

# %%
a=int(input('Integer: ')) # input given 
if a%2==0 :# checks that input is divisible by '2'
    print('even')# if it is divisible by '2' it prints 'even'
else: # if it is not divisible by '2' it prints 'odd'
    print('odd')
# Out:
# Integer: 3
# odd

# %% [markdown]
# ### 9. Write a Python program to add 'ing' at the end of a given string (string length should be equal to or more than 3). If the given string already ends with 'ing' then add 'ly' instead.If the string length of the given string is less than 3, leave it unchanged

# %%
a=str(input('string: ')) #input as string
if len(a) < 3: #checks length is below 3 
        print('string') #if it is true it prints string 
elif a[-3:] == 'ing': #checks 3rd negative index it will add 'ly'
            print(string+'ly')
else:#3rd negative index it will add 'ing'
            print(string + 'ing')
# Out:
# string: as
# string

# %%
a=str(input('string: ')) #input as string
if len(a) < 3: #checks length is below 3 
        print('string') #if it is true it prints string 
elif a[-3:] == 'ing': #checks 3rd negative index it will add 'ly'
            print(a+'ly')
else:#3rd negative index it will add 'ing'
            print(a+ 'ing')
# Out:
# string: program
# programing

# %%
a=str(input('string: ')) #input as string
if len(a) < 3: #checks length is below 3 
        print('string') #if it is true it prints string 
elif a[-3:] == 'ing': #checks 3rd negative index it will add 'ly'
            print(a+'ly')
else:#3rd negative index it will add 'ing'
            print(a+ 'ing')
# Out:
# string: sweet
# sweeting

# %%
a=str(input('string: ')) #input as string
if len(a) < 3: #checks length is below 3 
        print('string') #if it is true it prints string 
elif a[-3:] == 'ing': #checks 3rd negative index it will add 'ly'
            print(a+'ly')
else:#3rd negative index it will add 'ing'
            print(a+ 'ing')
# Out:
# string: sting
# stingly

# %% [markdown]
# ### 11. Create a dynamic calculator which asks for numbers and operator and return the answers,
# * Example
# * Input: Type first number: 10",
# * Type any of this (+, -, *, /, %, **): ,*
# * Assignment-2 ,
# * Type second number: 19,
# * Output:Answer is 190

# %%
num1 = int(input(" First number: ")) # input as first number
operator = input("Type any of this (+, -, *, /, %, **): ") # using operator
num2 = float(input("Second number: "))# input as second number
if operator == "+": #adds two numbers 
    print("Answer is", num1 + num2)
if operator == "-": # subtracts two numbers
     print("Answer is", num1 - num2)
if operator == "*": #multiplies two numbers
     print("Answer is", num1 * num2)
if operator == "/":# divides two numbers
     print("Answer is", num1 / num2)
if operator == "%": #modulus 
     print("Answer is", num1 % num2)
if operator == "**": #exponential
     print("Answer is", num1 ** num2)
# Out:
#  First number: 10
# Type any of this (+, -, *, /, %, **): *
# Second number: 19
# Answer is 190.0

# %% [markdown]
# ### 12. Manoj Kumar has family and friends. Help him remind them who is who. Given a string with a name, return the relation of that person to Manoj Kumar.,Person Relation,Shiva father ,Letha mother, Tarun brother,Kavitha sister ,,Strange Coder

# %%
a=str(input('Manoj Relation ')) # giving input as monoj relation
if a == "Shiva": #checks name
                   print('Father')# prints relation
elif a == "Letha":#checks name
                   print('Mother')# prints relation
elif a == "Tarun":#checks name
                   print('Brother')# prints relation
elif a == "Kavitha":#checks name
                   print('Sister')# prints relation
else:#checks name
                   print('Stranger')# prints unknown
# Out:
# Manoj Relation Kavitha
# Sister

# %%
a=str(input('Manoj Relation ')) # giving input as monoj relation
if a == "Shiva": #checks name
                   print('Father')# prints relation
elif a == "Letha":#checks name
                   print('Mother')# prints relation
elif a == "Tarun":#checks name
                   print('Brother')# prints relation
elif a == "Kavitha":#checks name
                   print('Sister')# prints relation
else:#checks name
                   print('Stranger')
# Out:
# Manoj Relation Tarun
# Brother

# %%
a=str(input('Manoj Relation ')) # giving input as monoj relation
if a == "Shiva": #checks name
                   print('Father')# prints relation
elif a == "Letha":#checks name
                   print('Mother')# prints relation
elif a == "Tarun":#checks name
                   print('Brother')# prints relation
elif a == "Kavitha":#checks name
                   print('Sister')# prints relation
else:#checks name
                   print('Stranger')
# Out:
# Manoj Relation Letha
# Mother

# %%
a=str(input('Manoj Relation ')) # giving input as monoj relation
if a == "Shiva": #checks name
                   print('Father')# prints relation
elif a == "Letha":#checks name
                   print('Mother')# prints relation
elif a == "Tarun":#checks name
                   print('Brother')# prints relation
elif a == "Kavitha":#checks name
                   print('Sister')# prints relation
else:#checks name
                   print('Stranger')
# Out:
# Manoj Relation Shiva
# Father

# %% [markdown]
# ### 13. Write a python program that takes in a word and determines whether or not it is plural. Aplural word is one that ends with "s"

# %%
a = input("Word: ") # input given

if a.endswith('s'): #checks input  ends with 's'
    print("word is plural.") # if true it prints plural
else: # false it prints not plural
    print("word is not plural.")
# Out:
# Word: ayesha
# word is not plural.

# %%
a = input("Word: ") # input given

if a.endswith('s'): #checks input  ends with 's'
    print("word is plural.") # if true it prints plural
else: # false it prints not plural
    print("word is not plural.")
# Out:
# Word: pens
# word is plural.

# %% [markdown]
# ### 14. A company decided to give a bonus of 5% to employees if his/her year of service is more than 5 years.Ask user for their salary and year of service and print the net bonus amount

# %%
salary = int(input("Salary: ")) # input as salary
service_yrs = int(input("Years of service:")) #input as service years
if service_yrs > 5: # checks service years more than 5 years
    print("Yours salary(+Bonus) = ",salary + (salary)*5/100) # calculating bonus 
else: # if statement is false it executes else 
    print("You are not eligible for bonus as you have less service years")
# Out:
# Salary: 25000
# Years of service:6
# Yours salary(+Bonus) =  26250.0

# %%
salary = int(input("Salary: ")) # input as salary
service_yrs = int(input("Years of service:")) #input as service years
if service_yrs > 5: # checks service years more than 5 years
    print("Yours salary(+Bonus) = ",salary + (salary)*5/100) # calculating bonus 
else: # if statement is false it executes else 
    print("You are not eligible for bonus as you have less service years")
# Out:
# Salary: 25000
# Years of service:4
# You are not eligible for bonus as you have less service years

# %% [markdown]
# ### 15. Take values of length and breadth of a rectangle from the user and check if it is square or not.

# %%
a=int(input("enter the length of the figure: "))
b=int(input("enter the breadth of the figure"))
if a==b:
    print("the figure is a square")
else:
     print("the figure is not a square")
# Out:
# enter the length of the figure: 10
# enter the breadth of the figure10
# the figure is a square

# %%
a=int(input("enter the length of the figure: "))
b=int(input("enter the breadth of the figure"))
if a==b:
    print("the figure is a square")
else:
     print("the figure is not a square")
# Out:
# enter the length of the figure: 10
# enter the breadth of the figure78
# the figure is not a square

# %% [markdown]
# ### 16.Accept any city from the user and display the momentum of the city
# * "Hyderabad" : “charminar”
# * “Delhi” : “red fort
# * “Agra : Taj mahal
# ### If the city name is not given correctly, give him a warning message.

# %%
city = input("City name: ") #input as city name 
if city == "Hyderabad": #checks the city name 
    print("Charminar")# if it is true prints'charminar'
elif city == "Delhi":#checks the city name 
    print("Red Fort")# if it is true prints'charminar'
elif city == "Agra":#checks the city name 
    print("Taj Mahal")# if it is true prints'charminar'
else: # if all the statements are false  print wrong city
    print("Wrong City Name")
# Out:
# City name: Delhi
# Red Fort

# %%
city = input("City name: ") #input as city name 
if city == "Hyderabad": #checks the city name 
    print("Charminar")# if it is true prints'charminar'
elif city == "Delhi":#checks the city name 
    print("Red Fort")# if it is true prints'charminar'
elif city == "Agra":#checks the city name 
    print("Taj Mahal")# if it is true prints'charminar'
else: # if all the statements are false  print wrong city
    print("Wrong City Name")
# Out:
# City name: Hyderabad
# Charminar

# %%
city = input("City name: ") #input as city name 
if city == "Hyderabad": #checks the city name 
    print("Charminar")# if it is true prints'charminar'
elif city == "Delhi":#checks the city name 
    print("Red Fort")# if it is true prints'charminar'
elif city == "Agra":#checks the city name 
    print("Taj Mahal")# if it is true prints'charminar'
else: # if all the statements are false  print wrong city
    print("Wrong City Name")
# Out:
# City name: Agra
# Taj Mahal

# %% [markdown]
# ### 17.Write a program to check whether a person is eligible for voting or not (voting age>=18)

# %%
age = int(input("Age: ")) # input as age 
if age>=18:# checks age is above '18'
    print("You are eligible to vote") #if it is true prints eligible to vote
else: # if statement is false then it executes else
    print("You are not eligible to vote")
# Out:
# Age: 20
# You are eligible to vote

# %%
age = int(input("Age: ")) # input as age 
if age>=18:# checks age is above '18'
    print("You are eligible to vote") #if it is true prints eligible to vote
else: # if statement is false then it executes else
    print("You are not eligible to vote")
# Out:
# Age: 16
# You are not eligible to vote

# %% [markdown]
# ### 18.Accept three sides of the triangle and check whether the triangle is possible or not.(Triangle is possible only when the sum of any two sides is greater than 3 rdside

# %%
x = int(input("Enter the first angle: "))
y = int(input("Enter the second angle: "))
z = int(input("Enter the third angle: ")) # to check whether sum of angles are 180 and each angle
if(x != 0 and y != 0 and z != 0 and (x + y + z)== 180): # not equal to 0
  if((x + y)>= z or (x + z)>= y or (y + z)>= x):   # Checking sum of 2 angles greater than the third 
      print("Yes,triangle is valid")
else: 
      print("No,triangle not possible")
# Out:
# Enter the first angle: 100
# Enter the second angle: 20
# Enter the third angle: 60
# Yes,triangle is valid

# %%
x = int(input("Enter the first angle: "))
y = int(input("Enter the second angle: "))
z = int(input("Enter the third angle: ")) # to check whether sum of angles are 180 and each angle
if(x != 0 and y != 0 and z != 0 and (x + y + z)== 180): # not equal to 0
  if((x + y)>= z or (x + z)>= y or (y + z)>= x):   # Checking sum of 2 angles greater than the third 
      print("Yes,triangle is valid")
else: 
      print("No,triangle not possible")
# Out:
# Enter the first angle: 70
# Enter the second angle: 40
# Enter the third angle: 30
# No,triangle not possible
