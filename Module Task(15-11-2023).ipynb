# %% [markdown]
# # Mandatory Task(15-11-2023)
# # Module:
# * In Python, Modules are simply files with the “. py” extension containing Python code that can be imported inside another Python Program.
# * A Python module is a file containing Python definitions and statements.
# * A module can define functions, classes, and variables.
# * A module can also include runnable code.
# * Grouping related code into a module makes the code easier to understand and use. It also makes the code logically organized.
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Creating module:

# %% [markdown]
# ![module%20create.jpg](attachment:module%20create.jpg)

# %% [markdown]
# #### Import module:

# %% [markdown]
# ![module%20impot.jpg](attachment:module%20impot.jpg)

# %% [markdown]
# ## Alias:-
# * Creating an alias for a module in Python allows you to refer to the module with a different name within your code.
# * This can be helpful if the original module name is lengthy or if you want to avoid naming conflicts.
# * This technique can be particularly useful when dealing with modules with long names.
# * when you need to differentiate between similar modules or prevent namespace clashes.
# ![](https://gyanipandit.com/programming/wp-content/uploads/2022/11/THE-AS-KEYWORD-IN-PYTHONFOR-CREATING-ALIAS-FOR-MODULE.jpg)

# %% [markdown]
# ## Defining Maths Formulae Functions

# %% [markdown]
# ![Screenshot%20%284%29.png](attachment:Screenshot%20%284%29.png)

# %% [markdown]
# ## Calling function

# %% [markdown]
# ![Screenshot%20%288%29.png](attachment:Screenshot%20%288%29.png)

# %% [markdown]
# ## Defining Physics Formulae Functions

# %% [markdown]
# ![Screenshot%20%286%29.png](attachment:Screenshot%20%286%29.png)

# %% [markdown]
# ## Calling physics functions

# %% [markdown]
# ![Screenshot%20%289%29.png](attachment:Screenshot%20%289%29.png)
